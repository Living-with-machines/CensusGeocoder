# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import numpy as np
# Out:
# /Users/wknq25/opt/anaconda3/envs/geocoder_py38/lib/python3.8/site-packages/geopandas/_compat.py:123: UserWarning: The Shapely GEOS version (3.11.1-CAPI-1.17.1) is incompatible with the GEOS version PyGEOS was compiled with (3.10.4-CAPI-1.16.2). Conversions between both will be slow.
#   warnings.warn(
# /var/folders/fg/_n1n9v7x7x1bk7m6gwfkv97m0000gp/T/ipykernel_2810/3767639949.py:2: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
#
# import os
# os.environ['USE_PYGEOS'] = '0'
# import geopandas
#
# ...

# %%
year = 1851
country = "EW"

# %%
gb1900_data_file = f"output_geom_test/{year}/{country}/gb1900/gb1900_{country}_{year}.geojson"
# open_roads_data = "../output_geom_test/1901/EW/os_open_roads/os_open_roads_EW_1901.geojson"

# %%
gb1900 = gpd.read_file(gb1900_data_file)
gb1900.head()
# Out:
#                            gb1900_EW_1851                    pin_id  \
# 0  52d73146c4931d000e00b112_12480_3610002  52d73146c4931d000e00b112
# 1  52d731e3c4931d000800a2a0_12480_3610002  52d731e3c4931d000800a2a0
# 2  53f75f10e678ef000b00024c_12480_3610002  53f75f10e678ef000b00024c
# 3  52d73131c4931d000500b249_12480_3610002  52d73131c4931d000500b249
# 4  52d7316fc4931d000e00b11d_12480_3610002  52d7316fc4931d000e00b11d
#
#        final_text  conparid_51-91  CEN_1851  count  dist_calc  \
# 0        VICARAGE           12480   3610002      1        NaN
# 1  POLICE STATION           12480   3610002      1        NaN
# 2       TY NEWYDD           12480   3610002      1        NaN
# 3          SMITHY           12480   3610002      1        NaN
# 4  WHITE LION INN           12480   3610002      1        NaN
#
#                         geometry
# 0  POINT (320949.215 328423.258)
# 1  POINT (320974.573 328029.188)
# 2  POINT (320859.559 327007.848)
# 3  POINT (320959.605 328837.618)
# ...

# %%
linked_geoms = pd.read_csv("analysis_alignment_test3/1851/EW/link_lkup_merged_geoms.tsv", sep = "\t", nrows = 100)
linked_geoms.head()
# Out:
#      RecID  os_open_roads_EW_1851  rapidfuzzy_wratio_s_x  \
# 0  3747963                    NaN                    NaN
# 1  3747964                    NaN                    NaN
# 2  3747965                    NaN                    NaN
# 3  3747966                    NaN                    NaN
# 4  3747967                    NaN                    NaN
#
#                           gb1900_EW_1851  rapidfuzzy_wratio_s_y     geocode  \
# 0                                    NaN                    NaN  not_linked
# 1                                    NaN                    NaN  not_linked
# 2  5856c6ef2c66dc10b8013bbe_1254_1200001                    1.0      gb1900
# 3  5856c6ef2c66dc10b8013bbe_1254_1200001                    1.0      gb1900
# 4  5856c6ef2c66dc10b8013bbe_1254_1200001                    1.0      gb1900
#
#                    unique_add_id
# 0  BASINGSTOKE ROAD_1254_1190002
# 1  BASINGSTOKE ROAD_1254_1190002
# 2      WASING PLACE_1254_1200001
# ...
